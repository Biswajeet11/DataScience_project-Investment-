# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
round2_cleaned=pd.read_csv(r'C:\Users\Biswajeet\Desktop\Projects Kaggle\rounds2_cleaned.csv')
companies_cleaned=pd.read_csv(r'C:\Users\Biswajeet\Desktop\Projects Kaggle\companies_cleaned.csv',sep='\t')

# %%
round2_cleaned.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /organization/-qounter
# 2               /organization/-qounter
# 3  /organization/-the-one-of-them-inc-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
companies_cleaned.head()
# Out:
#                              permalink                    name  \
# 0                  /organization/-fame                   #fame
# 1               /organization/-qounter                :Qounter
# 2  /organization/-the-one-of-them-inc-  (THE) ONE of THEM,Inc.
# 3                /organization/0-6-com                 0-6.com
# 4       /organization/004-technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
companies_cleaned.loc[~companies_cleaned['permalink'].isin(round2_cleaned['company_permalink']),:]
# Out:
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list, status, country_code, state_code, region, city, founded_at]
# Index: []

# %%
round2_cleaned.loc[~round2_cleaned['company_permalink'].isin(companies_cleaned['permalink']),:]
# Out:
# Empty DataFrame
# Columns: [company_permalink, funding_round_permalink, funding_round_type, funding_round_code, funded_at, raised_amount_usd]
# Index: []

# %%
round2_cleaned.isnull().sum()
# Out:
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
companies_cleaned.isnull().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
data=pd.merge(companies_cleaned,round2_cleaned,how='inner',left_on='permalink',right_on='company_permalink')
data
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
data.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'status',
#        'country_code', 'state_code', 'region', 'city', 'founded_at',
#        'company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd'],
#       dtype='object')

# %%
len(data.permalink.unique())
# Out:
# 66368

# %%
data.isnull().sum()
# Out:
# permalink                      0
# name                           1
# homepage_url                6134
# category_list               3410
# status                         0
# country_code                8678
# state_code                 10946
# region                     10167
# city                       10164
# founded_at                 20521
# company_permalink              0
# funding_round_permalink        0
# funding_round_type             0
# funding_round_code         83809
# funded_at                      0
# raised_amount_usd          19990
# dtype: int64

# %%
map=pd.read_csv(r"E:\a-z kaggle\Teclov-data-code-project-forudemy\Teclov_data_code_project_forudemy\mapping.csv")
map.describe()
# Out:
#        Automotive & Sports      Blanks  Cleantech / Semiconductors  \
# count           688.000000  688.000000                  688.000000
# mean              0.031977    0.001453                    0.077035
# std               0.176066    0.038125                    0.266841
# min               0.000000    0.000000                    0.000000
# 25%               0.000000    0.000000                    0.000000
# 50%               0.000000    0.000000                    0.000000
# 75%               0.000000    0.000000                    0.000000
# max               1.000000    1.000000                    1.000000
#
#        Entertainment      Health  Manufacturing  News, Search and Messaging  \
# count     688.000000  688.000000     688.000000                  688.000000
# mean        0.129360    0.091570       0.058140                    0.104651
# std         0.335843    0.288627       0.234177                    0.306326
# ...

# %%
map
# Out:
#                   category_list  Automotive & Sports  Blanks  \
# 0                           NaN                    0       1
# 1                            3D                    0       0
# 2                   3D Printing                    0       0
# 3                 3D Technology                    0       0
# 4                    Accounting                    0       0
# 5              Active Lifestyle                    0       0
# 6                  Ad Targeting                    0       0
# 7            Advanced Materials                    0       0
# 8              Adventure Travel                    1       0
# 9                   Advertising                    0       0
# 10        Advertising Exchanges                    0       0
# 11         Advertising Networks                    0       0
# 12        Advertising Platforms                    0       0
# 13                       Advice                    0       0
# ...

# %%
round((100*(data.isnull().sum())/len(data.index)))
# Out:
# permalink                   0.0
# name                        0.0
# homepage_url                5.0
# category_list               3.0
# status                      0.0
# country_code                8.0
# state_code                 10.0
# region                      9.0
# city                        9.0
# founded_at                 18.0
# company_permalink           0.0
# funding_round_permalink     0.0
# funding_round_type          0.0
# funding_round_code         73.0
# funded_at                   0.0
# raised_amount_usd          17.0
# dtype: float64

# %%
data=data.drop(['homepage_url','state_code','region','city','founded_at','funding_round_code'],axis=1)

# %%
data
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
data.raised_amount_usd.describe()
# Out:
# count    9.495900e+04
# mean     1.042687e+07
# std      1.148212e+08
# min      0.000000e+00
# 25%      3.225000e+05
# 50%      1.680511e+06
# 75%      7.000000e+06
# max      2.127194e+10
# Name: raised_amount_usd, dtype: float64

# %%
data=data[~np.isnan(data.raised_amount_usd)]
data
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 15                                        /organization/1
# 16                              /organization/1-2-3-listo
# 20                            /organization/1-800-doctors
# ...

# %%
round((100*(data.raised_amount_usd).isnull().sum())/len(data.raised_amount_usd))
# Out:
# 0.0

# %%
country_codes=data.country_code.astype('category')
country_codes
# Out:
# 0         IND
# 2         USA
# 3         NaN
# 4         CHN
# 6         HKG
# 7         CAN
# 8         CAN
# 9         USA
# 10        USA
# 11        USA
# 12        USA
# 13        USA
# 15        USA
# 16        CHL
# 20        USA
# 21        USA
# 22        USA
# 23        USA
# 24        USA
# 25        USA
# 26        USA
# 27        USA
# 28        GBR
# 29        GBR
# 30        USA
# 31        USA
# 32        NaN
# 34        USA
# 35        USA
# 36        USA
#          ...
# 114917    GBR
# 114918    GBR
# 114919    GBR
# 114920    USA
# 114921    USA
# 114922    USA
# 114923    USA
# 114924    USA
# 114925    USA
# 114926    USA
# 114928    MYS
# 114929    MYS
# 114930    MYS
# 114931    MYS
# 114932    USA
# 114933    USA
# 114934    USA
# 114935    USA
# 114936    USA
# 114937    AUT
# 114938    GBR
# 114939    GBR
# 114940    GBR
# 114941    CHN
# 114942    HRV
# 114943    HRV
# 114944    HRV
# 114945    HRV
# 114947    USA
# 114948    NaN
# ...

# %%
country_codes.value_counts()
# Out:
# USA    62049
# GBR     5019
# CAN     2616
# CHN     1927
# IND     1649
# FRA     1451
# ISR     1364
# ESP     1074
# DEU     1042
# AUS      649
# RUS      588
# IRL      563
# SWE      560
# SGP      546
# NLD      532
# JPN      485
# ITA      483
# BRA      483
# CHE      437
# KOR      432
# CHL      432
# FIN      382
# DNK      314
# ARG      297
# BEL      293
# HKG      250
# TUR      196
# NOR      191
# BGR      190
# MEX      189
#        ...
# KHM        2
# DOM        2
# MAR        2
# MAF        2
# KWT        2
# NIC        2
# ZMB        2
# KAZ        2
# TUN        2
# SOM        1
# SYC        1
# SEN        1
# TGO        1
# QAT        1
# UZB        1
# PSE        1
# PRY        1
# OMN        1
# DMA        1
# BLM        1
# MNE        1
# MKD        1
# BRB        1
# LAO        1
# IRN        1
# HND        1
# GRD        1
# GGY        1
# DZA        1
# KNA        1
# Name: country_code, Length: 134, dtype: int64

# %%
data=data[~pd.isnull(data.country_code)]
data
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 2                                  /organization/-qounter
# 4                                   /organization/0-6-com
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 15                                        /organization/1
# 16                              /organization/1-2-3-listo
# 20                            /organization/1-800-doctors
# 21               /organization/1-800-publicrelations-inc-
# ...

# %%
round(100*(country_codes.value_counts())/len(data.country_code))
# Out:
# USA    70.0
# GBR     6.0
# CAN     3.0
# CHN     2.0
# IND     2.0
# FRA     2.0
# ISR     2.0
# ESP     1.0
# DEU     1.0
# AUS     1.0
# RUS     1.0
# IRL     1.0
# SWE     1.0
# SGP     1.0
# NLD     1.0
# JPN     1.0
# ITA     1.0
# BRA     1.0
# CHE     0.0
# KOR     0.0
# CHL     0.0
# FIN     0.0
# DNK     0.0
# ARG     0.0
# BEL     0.0
# HKG     0.0
# TUR     0.0
# NOR     0.0
# BGR     0.0
# MEX     0.0
#        ...
# KHM     0.0
# DOM     0.0
# MAR     0.0
# MAF     0.0
# KWT     0.0
# NIC     0.0
# ZMB     0.0
# KAZ     0.0
# TUN     0.0
# SOM     0.0
# SYC     0.0
# SEN     0.0
# TGO     0.0
# QAT     0.0
# UZB     0.0
# PSE     0.0
# PRY     0.0
# OMN     0.0
# DMA     0.0
# BLM     0.0
# MNE     0.0
# MKD     0.0
# BRB     0.0
# LAO     0.0
# IRN     0.0
# HND     0.0
# GRD     0.0
# GGY     0.0
# DZA     0.0
# KNA     0.0
# Name: country_code, Length: 134, dtype: float64

# %%
round((100*(data.isnull().sum())/len(data.index)))
# Out:
# permalink                  0.0
# name                       0.0
# category_list              1.0
# status                     0.0
# country_code               0.0
# company_permalink          0.0
# funding_round_permalink    0.0
# funding_round_type         0.0
# funded_at                  0.0
# raised_amount_usd          0.0
# dtype: float64

# %%
data=data[~pd.isnull(data.category_list)]
data
# Out:
#                                                 permalink  \
# 0                                     /organization/-fame
# 2                                  /organization/-qounter
# 4                                   /organization/0-6-com
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 15                                        /organization/1
# 16                              /organization/1-2-3-listo
# 20                            /organization/1-800-doctors
# 21               /organization/1-800-publicrelations-inc-
# ...

# %%
round((100*(data.isnull().sum())/len(data.index)))
# Out:
# permalink                  0.0
# name                       0.0
# category_list              0.0
# status                     0.0
# country_code               0.0
# company_permalink          0.0
# funding_round_permalink    0.0
# funding_round_type         0.0
# funded_at                  0.0
# raised_amount_usd          0.0
# dtype: float64

# %%
data.describe()
# Out:
#        raised_amount_usd
# count       8.852900e+04
# mean        1.047385e+07
# std         1.118118e+08
# min         0.000000e+00
# 25%         3.705180e+05
# 50%         1.800000e+06
# 75%         7.100000e+06
# max         2.127194e+10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88529 entries, 0 to 114947
# Data columns (total 10 columns):
# permalink                  88529 non-null object
# name                       88528 non-null object
# category_list              88529 non-null object
# status                     88529 non-null object
# country_code               88529 non-null object
# company_permalink          88529 non-null object
# funding_round_permalink    88529 non-null object
# funding_round_type         88529 non-null object
# funded_at                  88529 non-null object
# raised_amount_usd          88529 non-null float64
# dtypes: float64(1), object(9)
# memory usage: 7.4+ MB

# %%
100*(len(data.index)/len(round2_cleaned.index))
# Out:
# 77.01589400516751

# %%
data.to_csv('data_cleaned.csv',sep=',',index=False)
