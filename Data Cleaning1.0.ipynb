# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
companies=pd.read_csv(r'E:\a-z kaggle\Teclov-data-code-project-forudemy\Teclov_data_code_project_forudemy\companies.txt',delimiter='	',engine='python',encoding='ISO-8859-1')
rounds2=pd.read_csv(r'E:\a-z kaggle\Teclov-data-code-project-forudemy\Teclov_data_code_project_forudemy\rounds2.csv',encoding='ISO-8859-1')
companies
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# 5                       /Organization/01Games-Technology
# 6                    /Organization/0Ndine-Biomedical-Inc
# 7                                   /Organization/0Xdata
# 8                                        /Organization/1
# 9                              /Organization/1-2-3-Listo
# 10                                 /Organization/1-4-All
# 11                        /Organization/1-618-Technology
# 12                           /Organization/1-800-Dentist
# 13                           /Organization/1-800-Doctors
# 14              /Organization/1-800-Publicrelations-Inc-
# ...

# %%
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# ...

# %%
rounds2.head()
# Out:
#                      company_permalink  \
# 0                  /organization/-fame
# 1               /ORGANIZATION/-QOUNTER
# 2               /organization/-qounter
# 3  /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                /organization/0-6-com
#
#                            funding_round_permalink funding_round_type  \
# 0  /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1  /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# 2  /funding-round/b44fbb94153f6cdef13083530bb48030               seed
# 3  /funding-round/650b8f704416801069bb178a1418776b            venture
# 4  /funding-round/5727accaeaa57461bd22a9bdd945382d            venture
#
#   funding_round_code   funded_at  raised_amount_usd
# 0                  B  05-01-2015         10000000.0
# 1                  A  14-10-2014                NaN
# 2                NaN  01-03-2014           700000.0
# 3                  B  30-01-2014          3406878.0
# ...

# %%
companies.describe()
# Out:
#                                 permalink   name                homepage_url  \
# count                               66368  66367                       61310
# unique                              66368  66102                       61191
# top     /Organization/Sonexa-Therapeutics  Roost  http://www.askforoffer.com
# freq                                    1      4                           5
#
#        category_list     status country_code state_code       region  \
# count          63220      66368        59410      57821        58338
# unique         27296          4          137        311         1092
# top         Software  operating          USA         CA  SF Bay Area
# freq            3995      53034        37601      12900         8804
#
#                  city  founded_at
# count           58340       51147
# unique           5111        3978
# top     San Francisco  01-01-2012
# freq             3526        2730

# %%
rounds2.describe()
# Out:
#        raised_amount_usd
# count       9.495900e+04
# mean        1.042687e+07
# std         1.148212e+08
# min         0.000000e+00
# 25%         3.225000e+05
# 50%         1.680511e+06
# 75%         7.000000e+06
# max         2.127194e+10

# %%
companies['permalink']=companies['permalink'].str.lower()
companies_length=len(companies.permalink.unique())
companies_length
# Out:
# 66368

# %%
rounds2['company_permalink']=rounds2['company_permalink'].str.lower()
round_length=len(rounds2.company_permalink.unique())
round_length
# Out:
# 66370

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
# permalink        66368 non-null object
# name             66367 non-null object
# homepage_url     61310 non-null object
# category_list    63220 non-null object
# status           66368 non-null object
# country_code     59410 non-null object
# state_code       57821 non-null object
# region           58338 non-null object
# city             58340 non-null object
# founded_at       51147 non-null object
# dtypes: object(10)
# memory usage: 5.1+ MB

# %%
rounds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
rounds2.loc[~rounds2['company_permalink'].isin(companies['permalink']),:]
# Out:
#                                         company_permalink  \
# 29597                             /organization/e-cãbica
# 31863        /organization/energystone-games-çµç³æ¸¸æ
# 45176                /organization/huizuche-com-æ ç§ÿè½¦
# 58473              /organization/magnet-tech-ç£ç³ç§æ
# 101036  /organization/tipcat-interactive-æ²èÿä¿¡æ¯ç...
# 109969             /organization/weiche-tech-åè½¦ç§æ
# 113839                 /organization/zengame-ç¦
# æ¸¸ç§æ
#
#                                 funding_round_permalink funding_round_type  \
# 29597   /funding-round/8491f74869e4fe8ba9c378394f8fbdea               seed
# 31863   /funding-round/b89553f3d2279c5683ae93f45a21cfe0               seed
# 45176   /funding-round/8f8a32dbeeb0f831a78702f83af78a36               seed
# 58473   /funding-round/8fc91fbb32bc95e97f151dd0cb4166bf               seed
# 101036  /funding-round/41005928a1439cb2d706a43cb661f60f               seed
# ...

# %%
rounds2.iloc[[29597,31863,45176,58473,101036,109969,113839],:]
# Out:
#                                         company_permalink  \
# 29597                             /organization/e-cãbica
# 31863        /organization/energystone-games-çµç³æ¸¸æ
# 45176                /organization/huizuche-com-æ ç§ÿè½¦
# 58473              /organization/magnet-tech-ç£ç³ç§æ
# 101036  /organization/tipcat-interactive-æ²èÿä¿¡æ¯ç...
# 109969             /organization/weiche-tech-åè½¦ç§æ
# 113839                 /organization/zengame-ç¦
# æ¸¸ç§æ
#
#                                 funding_round_permalink funding_round_type  \
# 29597   /funding-round/8491f74869e4fe8ba9c378394f8fbdea               seed
# 31863   /funding-round/b89553f3d2279c5683ae93f45a21cfe0               seed
# 45176   /funding-round/8f8a32dbeeb0f831a78702f83af78a36               seed
# 58473   /funding-round/8fc91fbb32bc95e97f151dd0cb4166bf               seed
# 101036  /funding-round/41005928a1439cb2d706a43cb661f60f               seed
# ...

# %%
import chardet
rounds33=open(r'E:\a-z kaggle\Teclov-data-code-project-forudemy\Teclov_data_code_project_forudemy\rounds2.csv','rb').read()
result=chardet.detect(rounds33)

# %%
result
# Out:
# {'confidence': 0.4186155476629225,
#  'encoding': 'Windows-1254',
#  'language': 'Turkish'}

# %%
result['encoding']
# Out:
# 'Windows-1254'

# %%
rounds2['company_permalink']=rounds2['company_permalink'].str.encode('utf-8').str.decode('ascii', 'ignore')
rounds2.loc[~rounds2['company_permalink'].isin(companies['permalink']),:]
# Out:
#                                         company_permalink  \
# 77                                  /organization/10north
# 729                               /organization/51wofang-
# 2670                              /organization/adslinked
# 3166    /organization/aesthetic-everything-social-network
# 3291                 /organization/affluent-attach-club-2
# 4568                           /organization/allgu-outlet
# 8097                             /organization/asiansbook
# 8652                              /organization/atlye-gri
# 9784                                  /organization/axgaz
# 14311              /organization/boral-bikes-incorporated
# 14798                          /organization/brasil-oznio
# 14951                         /organization/bricopriv-com
# 15384                                   /organization/brv
# 16018                         /organization/bhner-eh-gmbh
# 16624                          /organization/canal-da-pea
# ...

# %%
len(rounds2['company_permalink'].unique())
# Out:
# 66368

# %%
len(companies['permalink'].unique())
# Out:
# 66368

# %%
companies.loc[~companies['permalink'].isin(rounds2['company_permalink']),:]
# Out:
#                                                permalink  \
# 43                               /organization/10â°north
# 426                  /organization/51wofang-æ å¿§ææ¿
# 1506                          /organization/adslinkedâ¢
# 1775   /organization/aesthetic-everythingâ®-social-ne...
# 1834              /organization/affluent-attachã©-club-2
# 2556                        /organization/allgã¤u-outlet
# 4567                         /organization/asiansbookâ¢
# 4903                           /organization/atã¶lye-gri
# 5490                               /organization/axã¨gaz
# 8131            /organization/borã©al-bikes-incorporated
# 8385                        /organization/brasil-ozã´nio
# 8477                       /organization/bricoprivã©-com
# 8710                                 /organization/bräv
# 9095                       /organization/bã¶hner-eh-gmbh
# 9441                        /organization/canal-da-peã§a
# ...

# %%
companies['permalink']=companies['permalink'].str.encode('utf-8').str.decode('ascii', 'ignore')

# %%
#checking not in round and is in company

companies.loc[~companies['permalink'].isin(rounds2['company_permalink']),:]
# Out:
# Empty DataFrame
# Columns: [permalink, name, homepage_url, category_list, status, country_code, state_code, region, city, founded_at]
# Index: []

# %%
#checking not in company and is in rounds
rounds2.loc[~rounds2['company_permalink'].isin(companies['permalink']),:]
# Out:
# Empty DataFrame
# Columns: [company_permalink, funding_round_permalink, funding_round_type, funding_round_code, funded_at, raised_amount_usd]
# Index: []

# %%
rounds2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /organization/-qounter
# 2                                  /organization/-qounter
# 3                     /organization/-the-one-of-them-inc-
# 4                                   /organization/0-6-com
# 5                          /organization/004-technologies
# 6                        /organization/01games-technology
# 7                     /organization/0ndine-biomedical-inc
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /organization/0xdata
# 10                                   /organization/0xdata
# 11                                   /organization/0xdata
# 12                                   /organization/0xdata
# 13                                        /organization/1
# 14                                        /organization/1
# ...

# %%
companies
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
rounds2.to_csv('rounds2_cleaned.csv',sep=',',index=False)
companies.to_csv('companies_cleaned.csv',sep='\t',index=False)
